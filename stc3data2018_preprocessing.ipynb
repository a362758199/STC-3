# %%
import json
with open('C:/Users/justin/seq2seq/stc-3_emotion_train.json','r',encoding ='utf16') as jsonfile:   #encoding：utf16
    origiondata = json.load(jsonfile)
    for i in range(10):
        pair = origiondata[i]
        posts = pair[0]
        comments = pair[1]
        post = posts[0]
        comment = comments[0]
        pemotion = posts[1]
        cemotion = comments[1]
        print(pair,posts,comments,post,comment,pemotion,cemotion,sep='\n',end='\n\n')
# Out:
# [['现在 刷 朋友 圈 最大 的 快乐 就是 看 代购 们 各种 直播 。 。 。 。 。', '5'], ['卧 槽 我 也 是', '4']]
# ['现在 刷 朋友 圈 最大 的 快乐 就是 看 代购 们 各种 直播 。 。 。 。 。', '5']
# ['卧 槽 我 也 是', '4']
# 现在 刷 朋友 圈 最大 的 快乐 就是 看 代购 们 各种 直播 。 。 。 。 。
# 卧 槽 我 也 是
# 5
# 4
#
# [['什么 时候 可以 一 觉 到 天亮 、', '0'], ['[ 可怜 ] 加油 ! ~ ~', '1']]
# ['什么 时候 可以 一 觉 到 天亮 、', '0']
# ['[ 可怜 ] 加油 ! ~ ~', '1']
# 什么 时候 可以 一 觉 到 天亮 、
# [ 可怜 ] 加油 ! ~ ~
# 0
# 1
#
# [['1200   差点 永远 睡 在 跑道 上 阿   [ 泪 ]', '2'], ['为什么 跑 那么 多 ? 会 死 人 的 ! !', '4']]
# ['1200   差点 永远 睡 在 跑道 上 阿   [ 泪 ]', '2']
# ['为什么 跑 那么 多 ? 会 死 人 的 ! !', '4']
# 1200   差点 永远 睡 在 跑道 上 阿   [ 泪 ]
# 为什么 跑 那么 多 ? 会 死 人 的 ! !
# 2
# 4
#
# [['各种 不 爽 。 。 。', '3'], ['咋 了 ? ?', '3']]
# ['各种 不 爽 。 。 。', '3']
# ['咋 了 ? ?', '3']
# 各种 不 爽 。 。 。
# 咋 了 ? ?
# 3
# 3
#
# [['不 活 成 自己 想 活 的 样子 , 就 不 算 活着 吧 。', '3'], ['存在 即 是 一切 , 一切 为了 存在 [ 坏笑 ]', '0']]
# ['不 活 成 自己 想 活 的 样子 , 就 不 算 活着 吧 。', '3']
# ['存在 即 是 一切 , 一切 为了 存在 [ 坏笑 ]', '0']
# 不 活 成 自己 想 活 的 样子 , 就 不 算 活着 吧 。
# 存在 即 是 一切 , 一切 为了 存在 [ 坏笑 ]
# 3
# 0
#
# ...
